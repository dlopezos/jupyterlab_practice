# %% [markdown]
# We are currently working in the following directory:

# %%
# !pwd
# Out:
# /c/Users/jlcod/Downloads/student_a7/student/jupyterlab_practice

# %% [markdown]
# To time how long it takes to run a Python cell, we could use the timeit command inside a cell as is shown below:
# ```
# for i in range(1_000_000):
#     i**2
# ```

# %%
# %%timeit
for i in range(1_000_000):
    i**2
# Out:
# 471 ms ± 10.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# !jupyter nbconvert --to html --no-input question12.ipynb
# Out:
# [NbConvertApp] Converting notebook question12.ipynb to html
# [NbConvertApp] Writing 278392 bytes to question12.html
